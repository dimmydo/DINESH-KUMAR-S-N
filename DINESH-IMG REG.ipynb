# %% [markdown]
# # IMAGE RECOGNITION

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
nine=os.listdir("D:/nine")
ajith=os.listdir("D:/Ajith")
sam=os.listdir("D:/sam")

# %%
limit = 10
ajith_image=[None]*limit
j=0
for i in ajith:
    if(j<limit):
        ajith_image[j]=imread("D:/Ajith/"+i)
        j+=1
    else:
        break

# %%
limit = 10
nine_image=[None]*limit
j=0
for i in nine:
    if(j<limit):
        nine_image[j]=imread("D:/nine/"+i)
        j+=1
    else:
        break

# %%
limit = 10
sam_image=[None]*limit
j=0
for i in sam:
    if(j<limit):
        sam_image[j]=imread("C:/Users/Zion_2232/Pictures/New folder/sam/"+i)
        j+=1
    else:
        break

# %%
imshow(nine_image[5])

# %%
ajith_image[9].shape
# Out:
# (159, 318, 3)

# %%
ajith_gray=[None]*limit
j=0
for i in ajith:
    if(j<limit):
        ajith_gray[j]=rgb2gray(ajith_image[j])
        j+=1
    else:
        bre

# %%
nine_gray=[None]*limit
j=0
for i in nine:
    if(j<limit):
        nine_gray[j]=rgb2gray(nine_image[j])
        j+=1
    else:
        break

# %%
sam_gray=[None]*limit
j=0
for i in sam:
    if(j<limit):
        sam_gray[j]=rgb2gray(sam_image[j])
        j+=1
    else:
        break

# %%
imshow(sam_gray[3])

# %%
imshow(nine_gray[3])

# %%
ajith_gray[4].shape
# Out:
# (163, 308)

# %%
for j in range (10):
    aj=ajith_gray[j]
    ajith_gray[j]=resize(aj,(512,512))

# %%
for j in range (10):
    dh=nine_gray[j]
    nine_gray[j]=resize(dh,(512,512))

# %%
for j in range (10):
    sa=sam_gray[j]
    sam_gray[j]=resize(sa,(512,512))

# %%
imshow(sam_gray[7])

# %%
imshow(nine_gray[3])

# %%
len_of_image_ajith=len(ajith_gray)
len_of_image_sam=len(sam_gray)
len_of_image_nine=len(nine_gray)

# %%
image_size_ajith=ajith_gray[1].shape
image_size_sam=sam_gray[1].shape
image_size_nine=nine_gray[1].shape

# %%
image_size_nine
# Out:
# (512, 512)

# %%
flatten_size_ajith=image_size_ajith[0]*image_size_ajith[1]
flatten_size_sam=image_size_sam[0]*image_size_sam[1]
flatten_size_nine=image_size_nine[0]*image_size_nine[1]

# %%
flatten_size_nine
# Out:
# 262144

# %%
for i in range(len_of_image_ajith):
    ajith_gray[i]=np.ndarray.flatten(ajith_gray[i]).reshape(flatten_size_ajith,1)

# %%
for i in range(len_of_image_sam):
    sam_gray[i]=np.ndarray.flatten(sam_gray[i]).reshape(flatten_size_sam,1)

# %%
for i in range(len_of_image_nine):
    nine_gray[i]=np.ndarray.flatten(nine_gray[i]).reshape(flatten_size_nine,1)

# %%
ajith_gray=np.dstack(ajith_gray)
sam_gray=np.dstack(sam_gray)
nine_gray=np.dstack(nine_gray)

# %%
ajith_gray=np.rollaxis(ajith_gray,axis=2,start=0)
sam_gray=np.rollaxis(sam_gray,axis=2,start=0)
nine_gray=np.rollaxis(nine_gray,axis=2,start=0)

# %%
ajith_gray.shape
# Out:
# (10, 262144, 1)

# %%
ajith_gray=ajith_gray.reshape(len_of_image_ajith,flatten_size_ajith)
sam_gray=sam_gray.reshape(len_of_image_sam,flatten_size_sam)
nine_gray=nine_gray.reshape(len_of_image_nine,flatten_size_nine)

# %%
ajith_gray.shape
# Out:
# (10, 262144)

# %%
ajith_data=pd.DataFrame(ajith_gray)
sam_data=pd.DataFrame(sam_gray)
nine_data=pd.DataFrame(nine_gray)

# %%
ajith_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.105302  0.106203  0.109272  0.114863  0.120880  0.127774  0.135703
# 1  0.469497  0.466969  0.471588  0.476207  0.482650  0.489955  0.497296
# 2  0.548098  0.548557  0.546826  0.545095  0.543364  0.541633  0.539902
# 3  0.964706  0.964706  0.964706  0.964706  0.964706  0.964706  0.964706
# 4  0.498994  0.499519  0.501079  0.503438  0.506074  0.509237  0.512912
# 5  0.917897  0.919114  0.914695  0.909955  0.901821  0.893687  0.887957
# 6  0.124739  0.125903  0.123825  0.121747  0.118364  0.114309  0.110594
# 7  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 8  0.595960  0.598732  0.594900  0.591068  0.586781  0.581851  0.576920
# 9  0.188741  0.199810  0.229233  0.269799  0.305740  0.336564  0.351263
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.144562  0.152757  0.160390  ...  0.079473  0.081511  0.082154  0.075261
# ...

# %%
sam_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.490868  0.490868  0.490868  0.490868  0.490868  0.490868  0.490868
# 1  0.427407  0.413392  0.424322  0.438337  0.452353  0.470696  0.491172
# 2  0.928168  0.928168  0.928168  0.928168  0.928168  0.928168  0.928168
# 3  0.656186  0.656412  0.657184  0.657956  0.659084  0.661382  0.664890
# 4  0.121141  0.122070  0.121442  0.120514  0.119585  0.118440  0.117090
# 5  0.236172  0.240560  0.235164  0.229769  0.223918  0.216897  0.209875
# 6  0.134856  0.136888  0.129512  0.122285  0.116632  0.110979  0.110917
# 7  0.475937  0.476552  0.478692  0.478839  0.478839  0.478839  0.480000
# 8  0.529098  0.529144  0.531127  0.534903  0.540239  0.545918  0.551869
# 9  0.739730  0.740144  0.739865  0.739450  0.739036  0.738120  0.736727
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.490868  0.490868  0.490868  ...  0.666172  0.666172  0.666172  0.666172
# ...

# %%
ajith_data["lebel"]="ajith"
sam_data["lebel"]="sam"
nine_data["lebel"]="nine"

# %%
ajith_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.392162  0.378332  0.368661  0.372058  0.370736  0.368748  0.374104
# 1   0.475937  0.476552  0.478692  0.478839  0.478839  0.478839  0.480000
# 2   0.427407  0.413392  0.424322  0.438337  0.452353  0.470696  0.491172
# 3   0.548098  0.548557  0.546826  0.545095  0.543364  0.541633  0.539902
# 4   0.121141  0.122070  0.121442  0.120514  0.119585  0.118440  0.117090
# 5   0.739730  0.740144  0.739865  0.739450  0.739036  0.738120  0.736727
# 6   0.656186  0.656412  0.657184  0.657956  0.659084  0.661382  0.664890
# 7   0.568192  0.568192  0.568170  0.562802  0.559506  0.559506  0.559506
# 8   0.188741  0.199810  0.229233  0.269799  0.305740  0.336564  0.351263
# 9   0.469497  0.466969  0.471588  0.476207  0.482650  0.489955  0.497296
# 10  0.490868  0.490868  0.490868  0.490868  0.490868  0.490868  0.490868
# 11  0.529098  0.529144  0.531127  0.534903  0.540239  0.545918  0.551869
# ...

# %%
x=kollywood_actors.values[:,:-1]
y=kollywood_actors.values[:,-1]

# %%
x
# Out:
# array([[0.3921620500696363, 0.37833209686393976, 0.36866055752652915,
#         ..., 0.4310459228364269, 0.41874739664242033, 0.4095054507296253],
#        [0.475936501231474, 0.4765521200800876, 0.47869246933282583, ...,
#         0.22449394335578468, 0.22449721037621592, 0.22449815005433327],
#        [0.42740698230145024, 0.413391591052635, 0.4243218332844155, ...,
#         0.15464308311312808, 0.12486068076937806, 0.16304940635531553],
#        ...,
#        [0.712360156824449, 0.7127312745098049, 0.7150847183287365, ...,
#         0.6132286210004071, 0.5991316463096537, 0.5935734934129927],
#        [0.9647058823529412, 0.9647058823529412, 0.9647058823529412, ...,
#         0.9647058823529412, 0.9647058823529412, 0.9647058823529412],
#        [0.928167843137255, 0.928167843137255, 0.928167843137255, ...,
#         0.8646121568627451, 0.8646121568627452, 0.8646121568627452]],
#       dtype=object)

# %%
y
# Out:
# array(['nine', 'sam', 'sam', 'ajith', 'sam', 'sam', 'sam', 'nine',
#        'ajith', 'ajith', 'sam', 'sam', 'nine', 'ajith', 'sam', 'ajith',
#        'ajith', 'nine', 'ajith', 'nine', 'nine', 'nine', 'sam', 'ajith',
#        'nine', 'nine', 'ajith', 'nine', 'ajith', 'sam'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred =clf.predict(x_test)
y_pred
# Out:
# array(['nine', 'nine', 'nine', 'nine', 'nine', 'nine', 'sam', 'nine',
#        'nine', 'nine', 'nine', 'nine', 'nine', 'nine', 'nine'],
#       dtype=object)

# %%
for i in range (6):
    predicted_images = (np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label:{0}'.format(y_pred[i]))
    plt.imshow(predicted_images,interpolation='nearest',cmap='gray')
    plt.show()

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.13333333333333333

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[0, 6, 0],
#        [0, 2, 1],
#        [0, 6, 0]], dtype=int64)
